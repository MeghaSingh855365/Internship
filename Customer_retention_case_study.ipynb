# %% [markdown]
# #                                 Customer Retention Case Study

# %% [markdown]
# Using this Case study we can actually predict from e-commerce where  Retailors business will work more. Using EDA we can find alot of ways where a Retailors should invest more and grow there buisness

# %%
#importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the data for dataframe
df=pd.read_excel(r'C:\Users\Administrator\Desktop\DataTrained_project\Flipo_intership\Customer_retention_dataset\customer_retention_dataset.xlsx')

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# # here we can see we have 269 rows and 71 column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# # Here from df.info we get all the information of the date set.
# 1)Here all values are of Object type only pincode is Numeric.
# 2)Integre is only 1 and object tye is 70.So we have to encode it to convert to numeric type
# 3)there is no null value present
# 4)memory storage is 149.3+ Kb

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %% [markdown]
# here we can see the statastic value of the dataset:
#     Min value:-110008
#     Max Value;-560037
#     3rd quartile value :-201310

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# here we can see no null value is present

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# using heatplot we can also check null value

# %%
df.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
df.rename(columns={"2 How old are you? ":"Age"},inplace=True)

# %%
df.Age.value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: Age, dtype: int64

# %%
sns.countplot(df["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
df.groupby('Age').size().plot(kind='pie', autopct='%.2f%%',colors=['tomato','gold'])
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.rename(columns={"1Gender of respondent":"Gender"},inplace=True)

# %%
df.Gender.value_counts()
# Out:
# Female    181
# Male       88
# Name: Gender, dtype: int64

# %%
sns.countplot(df["Gender"],hue=df['Age'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
df.groupby('Gender').size().plot(kind='pie', autopct='%.2f%%',colors=['tomato','gold'])
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.rename(columns={'3 Which city do you shop online from?':'City'}, inplace=True)

# %%
df.City.value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: City, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(df["City"],hue=df["Age"])
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
df.groupby('City').size().plot(kind='pie', autopct='%.2f%%',colors=['red','yellow'])
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # Accoding to the plot we observed that:
#     1)Max shopping is done by the age group of 31-40 years and List is done by 50yrs and above
#     2)Also we saw that in Gender:Max shopping is done by Female rather than male
#     3)We can also observe that Delhi is very famous in shopping its in high perioty and Bulandshahr is in least
#
# =>So,here we can give a coclusion that Ladies(Female) in the age group of 31-40years do the maximum shopping in Delhi region

# %%
df.rename(columns={'5 Since How Long You are Shopping Online ?':'Year'}, inplace=True)

# %%
df.rename(columns={'6 How many times you have made an online purchase in the past 1 year?':'Times'}, inplace=True)

# %%
df.rename(columns={'7 How do you access the internet while shopping on-line?':'Access'}, inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.countplot(df["Access"],hue=df["Online Shopping"])
# Out:
# <AxesSubplot:xlabel='Access', ylabel='count'>

# %% [markdown]
# 1)Here we can see that online shopping is min done with Dial-up only using destop it is done.

# %% [markdown]
# 2)Here we can also observe that Mobile Internet plot is very high.People use smartphone for doing shoping

# %% [markdown]
# 3)Here we can see more than wifi mobile internet is used

# %%
df.rename(columns={'8 Which device do you use to access the online shopping?':'Online Shopping'}, inplace=True)

# %%
df.head(4)
# Out:
#    Gender          Age           City  \
# 0    Male  31-40 years          Delhi
# 1  Female  21-30 years          Delhi
# 2  Female  21-30 years  Greater Noida
# 3    Male  21-30 years        Karnal
#
#    4 What is the Pin Code of where you shop online from?           Year  \
# 0                                             110009      Above 4 years
# 1                                             110030      Above 4 years
# 2                                             201308          3-4 years
# 3                                             132001          3-4 years
#
#                 Times           Access Online Shopping  \
# 0         31-40 times          Dial-up         Desktop
# 1  41 times and above            Wi-Fi      Smartphone
# 2  41 times and above  Mobile Internet      Smartphone
# 3  Less than 10 times  Mobile Internet      Smartphone
#
#   9 What is the screen size of your mobile device?\t\t\t\t\t\t                                          \
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(df["Online Shopping"],hue=df["Age"])
# Out:
# <AxesSubplot:xlabel='Online Shopping', ylabel='count'>

# %% [markdown]
# 1)Here we can observe that 21-30years of age group do more shopping usinng smart phone

# %% [markdown]
# 2) and also we can find out using Tablet only age group of 41-50 yrs do shopping.But ratio of 31-40 and 50 above is same in the least cateogry in shopping

# %%
plt.figure(figsize=(14,7))
sns.lineplot(df['City'],df['Year'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='Year'>

# %% [markdown]
# # Observation:

# %% [markdown]
# Male:-1) Here we can see Male from last 3-4 years are doing more shopping in Delhi.Greater Noida,Banaglore

# %% [markdown]
#     2) And it falls in Bulandshahr

# %% [markdown]
# Female:-1) from last 3-4 yrs femail shopping is increased in Banglore and noida

# %% [markdown]
#         2)and drasctically it dcreased in last 2-3 yrs in solan city and gurgaon

# %% [markdown]
#        3)again it ncreased and than decreased.

# %% [markdown]
# # So,here we can perdict that female shoping is keep increasing and decreasing in last 2-3 yrs

# %%
df['Perceived Trustworthiness'].value_counts().plot.pie(figsize = (6,6), autopct = '%.1f%%')
# Out:
# <AxesSubplot:ylabel='Perceived Trustworthiness'>

# %% [markdown]
# Here we see that Amazon is the trustworthy where people shop more

# %% [markdown]
# # Conclusion:- According to my servey

# %% [markdown]
# From this vistulization here I can conclude that:Retailors can invest more in as follows:

# %% [markdown]
# 1)Female do more shopping.So more things related to female can be added

# %% [markdown]
# 2)People find Amzone more save and worhty for shopping.So, amazon,Flipkart Retailors can use for there producats to add more

# %% [markdown]
# 3)City like Banglore,Delhi,Noida is more used for shopping.So,retailors from this place can thing to start a business it will give plus point to them

# %% [markdown]
# 4)people age of 31-40yrs its male or female they do more shopping.So, it can be keepen in mind and Reatilors can thing alot of ways to inhence there business

# %% [markdown]
# # In last I can say using Customer_retention_case_study I understood how e-commerce is growing in the market.So,as a data scientist we can grow the e-commerce market alot.
